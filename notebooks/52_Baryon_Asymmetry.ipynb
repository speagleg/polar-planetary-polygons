# %% [markdown]
# # Notebook 52: Baryon Asymmetry $\eta_B = J \cdot K^{15}/N$
#
# **Paper V.** The baryon asymmetry from the Bernoulli backbone:
# $\eta_B = J \cdot K^{C(N-1,2)} / N = 5.96 \times 10^{-10}$
# (Planck: $6.12 \times 10^{-10}$, 2.6% match).
#
# All results from `baryon_asymmetry.py` (7 tests).

# %%
from math import comb
from planetary_polygons.extensions.baryon_asymmetry import (
    instanton_power, eta_B, full_prediction,
)

result = full_prediction()
print(f"J = {result['J']:.4e} (Jarlskog from orbit CKM)")
print(f"K = {result['K']:.6f} (instanton fugacity)")
print(f"Power = C(N-1,2) = C(6,2) = {result['power']}")
print(f"\neta_B = J * K^{result['power']} / 7 = {result['eta_B']:.4e}")
print(f"eta_B (Planck) = {result['eta_obs']:.4e}")
print(f"Match: {result['match_pct']:+.1f}%")

# %% [markdown]
# ## Physical Interpretation

# %%
print(f"C(N-1, 2) = {comb(6,2)} = number of independent off-diagonal")
print(f"entries in the 6x6 mass matrix of Z_7 modes.")
print(f"\nEach entry involves one orbifold instanton tunnel.")
print(f"K per tunnel -> K^15 total suppression.")
print(f"J provides CP violation, 1/N = fractional baryon number.")
print(f"\nAll inputs derived from N=7 with zero free parameters.")
